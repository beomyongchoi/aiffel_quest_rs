# %% [markdown]
# # 네이버 영화리뷰 감정 분석: SentencePiece (unigram vs bpe) 비교 (v3)
#
# ## 목표
# 1. 네이버 영화리뷰 감정 분석 코퍼스에 SentencePiece의 `unigram`과 `bpe` 모델을 각각 적용하여 학습
# 2. 두 토크나이저를 적용한 감정 분석 모델(BiLSTM, 1D CNN)을 재학습하고 성능을 비교 분석

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from torch.nn.utils.rnn import pad_sequence
from soynlp.normalizer import emoticon_normalize
import sentencepiece as spm
import os

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. 데이터 로드 및 전처리

# %%
train_df = pd.read_table('ratings_train.txt')
test_df = pd.read_table('ratings_test.txt')

# %%
def preprocess_data(df, is_train=True):
    df_name = '훈련' if is_train else '테스트'
    print(f'--- {df_name} 데이터 전처리 ---')
    print(f'전처리 전 데이터 개수: {len(df)}')
    df.dropna(inplace=True)
    print(f'결측치 제거 후: {len(df)}개')
    if is_train:
        df.drop_duplicates(subset=['document'], inplace=True)
        print(f'중복 제거 후: {len(df)}개')
    df['document'] = df['document'].apply(lambda x: emoticon_normalize(x, num_repeats=2) if isinstance(x, str) else x)
    df.dropna(inplace=True) # emoticon_normalize 후 혹시 모를 결측치 재제거
    df = df[~df['document'].str.match('^[ㄱ-ㅎㅏ-ㅣ]+$', na=False)]
    min_char_len = 3
    max_char_len = 140
    df = df[df['document'].str.len() >= min_char_len]
    df['document'] = df['document'].str.slice(0, max_char_len)
    print(f'최종 데이터 개수: {len(df)}개')
    return df

train_df_clean = preprocess_data(train_df.copy(), is_train=True)
test_df_clean = preprocess_data(test_df.copy(), is_train=False)
# Out:
# --- 훈련 데이터 전처리 ---
# 전처리 전 데이터 개수: 150000
# 결측치 제거 후: 149995개
# 중복 제거 후: 146182개
# 최종 데이터 개수: 145594개
# --- 테스트 데이터 전처리 ---
# 전처리 전 데이터 개수: 50000
# 결측치 제거 후: 49997개
# 최종 데이터 개수: 49369개

# %% [markdown]
# ## 2. 모델 및 학습/평가 함수 정의

# %%
class LSTMModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, padding_idx=0):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=padding_idx)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, output_dim)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        embedded = self.embedding(x)
        lstm_out, (hidden, cell) = self.lstm(embedded)
        hidden = torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim=1)
        out = self.fc(hidden)
        return self.sigmoid(out)

class CNNModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, n_filters, filter_sizes, output_dim, dropout):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.convs = nn.ModuleList([
            nn.Conv1d(in_channels=embedding_dim, out_channels=n_filters, kernel_size=fs)
            for fs in filter_sizes
        ])
        self.fc = nn.Linear(len(filter_sizes) * n_filters, output_dim)
        self.dropout = nn.Dropout(dropout)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        embedded = self.embedding(x).permute(0, 2, 1)
        conved = [torch.relu(conv(embedded)) for conv in self.convs]
        pooled = [torch.max_pool1d(conv, conv.shape[2]).squeeze(2) for conv in conved]
        cat = self.dropout(torch.cat(pooled, dim=1))
        out = self.fc(cat)
        return self.sigmoid(out)

# %%
def train_and_evaluate(model, train_loader, val_loader, test_loader, num_epochs, device, lr=1e-3, model_name='Model'):
    model = model.to(device)
    criterion = nn.BCELoss().to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    
    print(f'--- {model_name} 모델 학습 시작 ---')
    for epoch in range(num_epochs):
        model.train()
        epoch_train_correct, epoch_train_total = 0, 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs).squeeze()
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            predicted = (outputs > 0.5).float()
            epoch_train_correct += (predicted == labels).sum().item()
            epoch_train_total += labels.size(0)
        avg_train_acc = epoch_train_correct / epoch_train_total

        model.eval()
        epoch_val_correct, epoch_val_total = 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs).squeeze()
                predicted = (outputs > 0.5).float()
                epoch_val_correct += (predicted == labels).sum().item()
                epoch_val_total += labels.size(0)
        avg_val_acc = epoch_val_correct / epoch_val_total
        
        print(f'Epoch [{epoch+1}/{num_epochs}] -> Train Acc: {avg_train_acc:.4f} | Val Acc: {avg_val_acc:.4f}')

    model.eval()
    test_correct, test_total = 0, 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs).squeeze()
            predicted = (outputs > 0.5).float()
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()
    test_accuracy = test_correct / test_total
    print(f'Final Test Accuracy: {test_accuracy:.4f}')
    return test_accuracy

# %% [markdown]
# ## 3. SentencePiece 모델 타입 비교 (unigram vs bpe)

# %%
# 말뭉치 파일 생성 (에러 방지를 위해 newline 문자 명시적 추가)
corpus_file = 'nsmc_corpus.txt'
with open(corpus_file, 'w', encoding='utf-8') as f:
    for doc in train_df_clean['document']:
        f.write(doc + '\n')

results = {}
vocab_size = 8000

for model_type in ['unigram', 'bpe']:
    print(f'{'='*50}')
    print(f'Running Experiment for model_type = {model_type.upper()}')
    print(f'{'='*50}')
    
    # 1. SentencePiece 모델 학습
    model_prefix = f'nsmc_spm_{model_type}'
    params = f'--input={corpus_file} --model_prefix={model_prefix} --vocab_size={vocab_size} --model_type={model_type}'
    spm.SentencePieceTrainer.Train(params)
    
    # 2. 토크나이저 로드 및 데이터 준비
    sp = spm.SentencePieceProcessor()
    sp.Load(f'{model_prefix}.model')
    
    def sp_tokenize(s, corpus):
        sequences = [s.EncodeAsIds(text) for text in corpus]
        sequences = [torch.tensor(seq, dtype=torch.long) for seq in sequences]
        return pad_sequence(sequences, batch_first=True, padding_value=0)
        
    X_train = sp_tokenize(sp, train_df_clean['document'].tolist())
    X_test = sp_tokenize(sp, test_df_clean['document'].tolist())
    y_train = torch.tensor(train_df_clean['label'].values, dtype=torch.float32)
    y_test = torch.tensor(test_df_clean['label'].values, dtype=torch.float32)
    
    val_size = 40000
    X_val, y_val = X_train[:val_size], y_train[:val_size]
    X_train_final, y_train_final = X_train[val_size:], y_train[val_size:]

    train_dataset = TensorDataset(X_train_final, y_train_final)
    val_dataset = TensorDataset(X_val, y_val)
    test_dataset = TensorDataset(X_test, y_test)

    batch_size = 512
    train_loader = DataLoader(train_dataset, shuffle=True, batch_size=batch_size)
    val_loader = DataLoader(val_dataset, shuffle=False, batch_size=batch_size)
    test_loader = DataLoader(test_dataset, shuffle=False, batch_size=batch_size)
    
    # 3. 모델 학습 및 평가
    if torch.backends.mps.is_available(): device = torch.device('mps')
    else: device = torch.device('cpu')
    
    VOCAB_SIZE = sp.GetPieceSize()
    EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM = 128, 128, 1
    NUM_EPOCHS, LEARNING_RATE = 7, 1e-3
    
    # BiLSTM
    bilstm_model = LSTMModel(VOCAB_SIZE, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM, padding_idx=0)
    bilstm_acc = train_and_evaluate(bilstm_model, train_loader, val_loader, test_loader, NUM_EPOCHS, device, lr=LEARNING_RATE, model_name=f'BiLSTM ({model_type})')
    
    # 1D CNN
    N_FILTERS, FILTER_SIZES, DROPOUT = 100, [3,4,5], 0.5
    cnn_model = CNNModel(VOCAB_SIZE, EMBEDDING_DIM, N_FILTERS, FILTER_SIZES, OUTPUT_DIM, DROPOUT)
    cnn_acc = train_and_evaluate(cnn_model, train_loader, val_loader, test_loader, NUM_EPOCHS, device, lr=LEARNING_RATE, model_name=f'1D CNN ({model_type})')
    
    results[model_type] = {'BiLSTM_Accuracy': bilstm_acc, 'CNN_Accuracy': cnn_acc}
# Out:
# ==================================================
# Running Experiment for model_type = UNIGRAM
# ==================================================
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=nsmc_corpus.txt --model_prefix=nsmc_spm_unigram --vocab_size=8000 --model_type=unigram
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: nsmc_corpus.txt
#   input_format:
#   model_prefix: nsmc_spm_unigram
#   model_type: UNIGRAM
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: nsmc_corpus.txt
# trainer_interface.cc(411) LOG(INFO) Loaded all 145594 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=5380734
# trainer_interface.cc(552) LOG(INFO) Done: 99.95% characters are covered.
# trainer_interface.cc(562) LOG(INFO) Alphabet size=1682
# trainer_interface.cc(563) LOG(INFO) Final character coverage=0.9995
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 145594 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=1890499
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 305522 seed sentencepieces
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 145594
# trainer_interface.cc(611) LOG(INFO) Done! 356666
# unigram_model_trainer.cc(602) LOG(INFO) Using 356666 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=157275 obj=15.3978 num_tokens=840450 num_tokens/piece=5.34382
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=145558 obj=14.3645 num_tokens=845509 num_tokens/piece=5.80874
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=109096 obj=14.4679 num_tokens=883090 num_tokens/piece=8.09461
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=108890 obj=14.4092 num_tokens=883713 num_tokens/piece=8.11565
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=81662 obj=14.6464 num_tokens=927916 num_tokens/piece=11.3629
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=81645 obj=14.5828 num_tokens=928059 num_tokens/piece=11.367
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=61233 obj=14.8449 num_tokens=971130 num_tokens/piece=15.8596
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=61233 obj=14.7805 num_tokens=971168 num_tokens/piece=15.8602
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=45924 obj=15.0731 num_tokens=1016035 num_tokens/piece=22.1243
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=45924 obj=15.0072 num_tokens=1016025 num_tokens/piece=22.1241
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=34443 obj=15.3283 num_tokens=1062380 num_tokens/piece=30.8446
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=34443 obj=15.261 num_tokens=1062357 num_tokens/piece=30.8439
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=25832 obj=15.6096 num_tokens=1109878 num_tokens/piece=42.9652
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=25832 obj=15.5377 num_tokens=1109898 num_tokens/piece=42.966
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=19374 obj=15.9227 num_tokens=1160573 num_tokens/piece=59.9036
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=19374 obj=15.8414 num_tokens=1160585 num_tokens/piece=59.9043
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=14530 obj=16.2676 num_tokens=1213370 num_tokens/piece=83.5079
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=14530 obj=16.1768 num_tokens=1213398 num_tokens/piece=83.5098
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=10897 obj=16.6431 num_tokens=1272041 num_tokens/piece=116.733
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=10897 obj=16.5314 num_tokens=1272524 num_tokens/piece=116.777
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=8800 obj=16.9014 num_tokens=1316762 num_tokens/piece=149.632
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=8800 obj=16.8188 num_tokens=1316855 num_tokens/piece=149.643
# trainer_interface.cc(689) LOG(INFO) Saving model: nsmc_spm_unigram.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: nsmc_spm_unigram.vocab
# --- BiLSTM (unigram) 모델 학습 시작 ---
# Epoch [1/7] -> Train Acc: 0.6602 | Val Acc: 0.7705
# Epoch [2/7] -> Train Acc: 0.8139 | Val Acc: 0.8246
# Epoch [3/7] -> Train Acc: 0.8526 | Val Acc: 0.8399
# Epoch [4/7] -> Train Acc: 0.8714 | Val Acc: 0.8487
# Epoch [5/7] -> Train Acc: 0.8872 | Val Acc: 0.8508
# Epoch [6/7] -> Train Acc: 0.8988 | Val Acc: 0.8502
# Epoch [7/7] -> Train Acc: 0.9112 | Val Acc: 0.8518
# Final Test Accuracy: 0.8458
# --- 1D CNN (unigram) 모델 학습 시작 ---
# Epoch [1/7] -> Train Acc: 0.6512 | Val Acc: 0.7602
# Epoch [2/7] -> Train Acc: 0.7756 | Val Acc: 0.8114
# Epoch [3/7] -> Train Acc: 0.8238 | Val Acc: 0.8327
# Epoch [4/7] -> Train Acc: 0.8503 | Val Acc: 0.8427
# Epoch [5/7] -> Train Acc: 0.8634 | Val Acc: 0.8484
# Epoch [6/7] -> Train Acc: 0.8736 | Val Acc: 0.8508
# Epoch [7/7] -> Train Acc: 0.8818 | Val Acc: 0.8536
# Final Test Accuracy: 0.8484
# ==================================================
# Running Experiment for model_type = BPE
# ==================================================
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=nsmc_corpus.txt --model_prefix=nsmc_spm_bpe --vocab_size=8000 --model_type=bpe
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: nsmc_corpus.txt
#   input_format:
#   model_prefix: nsmc_spm_bpe
#   model_type: BPE
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: nsmc_corpus.txt
# trainer_interface.cc(411) LOG(INFO) Loaded all 145594 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=5380734
# trainer_interface.cc(552) LOG(INFO) Done: 99.95% characters are covered.
# trainer_interface.cc(562) LOG(INFO) Alphabet size=1682
# trainer_interface.cc(563) LOG(INFO) Final character coverage=0.9995
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 145594 sentences.
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 145594
# trainer_interface.cc(611) LOG(INFO) Done! 356666
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=109133 min_freq=87
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11379 size=20 all=110266 active=10535 piece=▁없
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8901 size=40 all=114804 active=15073 piece=▁정말
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6277 size=60 all=118386 active=18655 piece=▁생
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5238 size=80 all=122350 active=22619 piece=드라마
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4209 size=100 all=126119 active=26388 piece=▁감동
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4204 min_freq=73
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3612 size=120 all=128930 active=9024 piece=▁부
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3236 size=140 all=131273 active=11367 piece=▁애
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2855 size=160 all=133982 active=14076 piece=,,
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2644 size=180 all=136402 active=16496 piece=▁처
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2389 size=200 all=139215 active=19309 piece=▁이건
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2373 min_freq=64
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2218 size=220 all=141012 active=8699 piece=▁도
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2056 size=240 all=143989 active=11676 piece=들은
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1902 size=260 all=146692 active=14379 piece=부터
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1797 size=280 all=149521 active=17208 piece=▁심
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1683 size=300 all=151032 active=18719 piece=정도
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=170 size=2520 all=281544 active=14477 piece=▁블랙
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=169 size=2540 all=282269 active=15202 piece=▁끝나고
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=167 size=2560 all=282695 active=15628 piece=레스
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=165 size=2580 all=283592 active=16525 piece=아라
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=164 size=2600 all=284300 active=17233 piece=끼리
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=164 min_freq=22
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=162 size=2620 all=284986 active=14845 piece=▁안됨
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=160 size=2640 all=285548 active=15407 piece=▁십
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=159 size=2660 all=286461 active=16320 piece=▁불쾌
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=158 size=2680 all=286985 active=16844 piece=▁더이상
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=156 size=2700 all=287724 active=17583 piece=▁밥
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=156 min_freq=21
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=155 size=2720 all=288515 active=15137 piece=불가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=154 size=2740 all=289405 active=16027 piece=▁감명
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=153 size=2760 all=290217 active=16839 piece=점주는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=152 size=2780 all=290833 active=17455 piece=년전에
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=150 size=2800 all=291719 active=18341 piece=▁가서
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=150 min_freq=21
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=149 size=2820 all=292320 active=15181 piece=▁오버
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=148 size=2840 all=293267 active=16128 piece=해준
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=147 size=2860 all=293926 active=16787 piece=▁설레
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=146 size=2880 all=294720 active=17581 piece=▁미치
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=145 size=2900 all=295142 active=18003 piece=독교
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=145 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=144 size=2920 all=295754 active=15329 piece=엄마
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=143 size=2940 all=296726 active=16301 piece=▁심각
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=142 size=2960 all=297287 active=16862 piece=▁슬프고
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=141 size=2980 all=297746 active=17321 piece=재미없다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=140 size=3000 all=298445 active=18020 piece=▁엉성한
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=140 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=138 size=3020 all=298945 active=15413 piece=이후
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=137 size=3040 all=299897 active=16365 piece=▁그걸
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=136 size=3060 all=300538 active=17006 piece=▁섬세
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=135 size=3080 all=301141 active=17609 piece=▁새벽
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=134 size=3100 all=301900 active=18368 piece=이션
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=134 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=133 size=3120 all=302608 active=15759 piece=줘야
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=132 size=3140 all=303394 active=16545 piece=▁닥
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=131 size=3160 all=303972 active=17123 piece=피소
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=130 size=3180 all=304377 active=17528 piece=▁헐리웃
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=129 size=3200 all=304931 active=18082 piece=▁작가가
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=129 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=128 size=3220 all=305586 active=15893 piece=▁재미있었다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=127 size=3240 all=306170 active=16477 piece=캐스팅
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=126 size=3260 all=306836 active=17143 piece=▁누구나
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=125 size=3280 all=307340 active=17647 piece=봤음
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=124 size=3300 all=307878 active=18185 piece=아버지
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=124 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=123 size=3320 all=308519 active=15979 piece=▁발견
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=122 size=3340 all=309070 active=16530 piece=▁처럼
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=121 size=3360 all=309560 active=17020 piece=물을
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=121 size=3380 all=310161 active=17621 piece=배우들의
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=120 size=3400 all=310651 active=18111 piece=▁시트콤
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=120 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=119 size=3420 all=311237 active=16094 piece=▁아줌마
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=118 size=3440 all=311997 active=16854 piece=▁덕분에
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=117 size=3460 all=312547 active=17404 piece=▁슬펐
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=116 size=3480 all=313200 active=18057 piece=▁노답
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=116 size=3500 all=313664 active=18521 piece=▁비현실
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=116 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=115 size=3520 all=314107 active=16114 piece=▁암튼
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=114 size=3540 all=314736 active=16743 piece=사수
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=114 size=3560 all=315150 active=17157 piece=▁재미있었어요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=113 size=3580 all=315689 active=17696 piece=▁최고입니다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=112 size=3600 all=316302 active=18309 piece=했네요
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=63 size=5780 all=365802 active=19706 piece=쓰는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=63 size=5800 all=366305 active=20209 piece=▁할때
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=63 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=63 size=5820 all=366634 active=18635 piece=▁제시카
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=62 size=5840 all=366827 active=18828 piece=겠어
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=62 size=5860 all=367567 active=19568 piece=치의
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=62 size=5880 all=367874 active=19875 piece=▁일으
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=62 size=5900 all=368264 active=20265 piece=▁되는데
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=62 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=5920 all=368375 active=18525 piece=nd
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=5940 all=368920 active=19070 piece=에다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=5960 all=369402 active=19552 piece=▁빵점
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=5980 all=369785 active=19935 piece=▁끝나서
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=6000 all=369921 active=20071 piece=▁다행이다
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=61 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=60 size=6020 all=370341 active=18916 piece=울뿐
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=60 size=6040 all=370759 active=19334 piece=▁절제
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=60 size=6060 all=371082 active=19657 piece=▁여러분
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=6080 all=371378 active=19953 piece=곳에
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=6100 all=372009 active=20584 piece=하루
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=59 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=6120 all=372271 active=18833 piece=▁전화
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=6140 all=372695 active=19257 piece=▁모른다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=6160 all=372886 active=19448 piece=▁시작해서
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=6180 all=373219 active=19781 piece=살때
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=6200 all=373733 active=20295 piece=▁부활
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=58 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=6220 all=374020 active=18951 piece=하기는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=6240 all=374146 active=19077 piece=▁한번더
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=57 size=6260 all=374297 active=19228 piece=다만
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=57 size=6280 all=374962 active=19893 piece=▁--
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=57 size=6300 all=375257 active=20188 piece=▁이다
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=57 min_freq=12
# trainer_interface.cc(689) LOG(INFO) Saving model: nsmc_spm_bpe.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: nsmc_spm_bpe.vocab
# --- BiLSTM (bpe) 모델 학습 시작 ---
# Epoch [1/7] -> Train Acc: 0.6697 | Val Acc: 0.7768
# Epoch [2/7] -> Train Acc: 0.8092 | Val Acc: 0.8233
# Epoch [3/7] -> Train Acc: 0.8507 | Val Acc: 0.8406
# Epoch [4/7] -> Train Acc: 0.8696 | Val Acc: 0.8468
# Epoch [5/7] -> Train Acc: 0.8827 | Val Acc: 0.8478
# Epoch [6/7] -> Train Acc: 0.8947 | Val Acc: 0.8448
# Epoch [7/7] -> Train Acc: 0.9068 | Val Acc: 0.8482
# Final Test Accuracy: 0.8434
# --- 1D CNN (bpe) 모델 학습 시작 ---
# Epoch [1/7] -> Train Acc: 0.6573 | Val Acc: 0.7623
# Epoch [2/7] -> Train Acc: 0.7801 | Val Acc: 0.8118
# Epoch [3/7] -> Train Acc: 0.8261 | Val Acc: 0.8340
# Epoch [4/7] -> Train Acc: 0.8493 | Val Acc: 0.8430
# Epoch [5/7] -> Train Acc: 0.8644 | Val Acc: 0.8481
# Epoch [6/7] -> Train Acc: 0.8735 | Val Acc: 0.8504
# Epoch [7/7] -> Train Acc: 0.8824 | Val Acc: 0.8520
# Final Test Accuracy: 0.8477

# %% [markdown]
# ## 4. 최종 결과 비교

# %%
results_df = pd.DataFrame(results).T
print(results_df)
# Out:
#          BiLSTM_Accuracy  CNN_Accuracy
# unigram         0.845774      0.848427
# bpe             0.843404      0.847678
